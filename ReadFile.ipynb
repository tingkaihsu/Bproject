# %%
import numpy as np
# from mpl_toolkits import mplot3d
# import matplotlib.pyplot as plt
import random
# plt.style.use('seaborn-poster')

# %%
def In(num, a, length):
    for i in range(length):
        if num == a[i]:
            return True
    return False

# %%
def Count(infilepath, part_pdg):
    with open(infilepath, 'r') as Input:
        lines = Input.readlines()
    events = 0
    for line in lines:
        if line.startswith('P'):
            pdata = line.split()
#             print(pdata[2])
            if In(pdata[2], part_pdg, len(part_pdg)):
                events += 1
    return events

# %%
##Read the file and construct the tree
# dtype = [('pdgid', int), ('px', float), ('py', float),
#          ('pz', float), ('energy', float), ('mass', float), ('vertex', int)]
def ReadFile(infilepath, outfilepath1, outfilepath2, experiments, charge_dic):
    with open(infilepath, 'r') as Input:
        lines = Input.readlines()
    Test = open(outfilepath1, 'w')
    Val = open(outfilepath2, 'w')
    
    charge = 0
    cur_ver = []
    cur_exp = {}
    first_exp = True
#     first_ver = True
    vertex = 0
    Bparts = []
    i = 1
    IsTest = True
    for line in lines:
        if line.startswith('E'):
            if vertex != 0:
                cur_exp[vertex] = cur_ver
#                 print(cur_ver)
                experiments.append(cur_exp)
                cur_exp = {}
#                 for exp in experiments:
#                     for pars in exp.values():
#                         for par in pars:
#                             print(par)
                ##need to clean the data of the Bparts
                Bparts = []
#                 mBparts = []
                vertex = 0
        elif line.startswith('V'):
            if vertex != 0:
                cur_exp[vertex] = cur_ver 
            cur_ver = []
            vertex += 1
        elif line.startswith('P'):
            pdata = line.split()
            cur_par = [int(pdata[2]), float(pdata[3]),
                               float(pdata[4]), float(pdata[5]),
                               float(pdata[6]), float(pdata[7]), 
                               int(pdata[11]), vertex]
            ##The second last one would be which vertex do particle decay 
            cur_ver.append(cur_par)
            ##when detecting 521 particles
            if int(pdata[2]) == 521:
                #meeting next 521 particle in different experiments
#                 print(charge)
#                 charge = 0
                Bparts = []
                ran = random.randint(1, 5)
                if ran == 1:
                    IsTest = False
                else:
                    IsTest = True
                if IsTest:
                    print('E 1 ', i, file = Test)
                else:
                    print('E 1 ', i, file = Val)
#                 print('E 1 ', i, file = Data)
                Bparts.append(int(pdata[11]))
                i = i + 1
#                 for j in cur_par:
#                     print(j, end = ' ', file = Val)
#                 print('', file = Val)
#                 print(cur_par, file = Output)
            if In(-cur_par[7], Bparts, len(Bparts)):
                Bparts.append(int(pdata[11]))
                if (cur_par[6] == 0):
                    ch = charge_dic.get(cur_par[0], 0)
                    if IsTest:
                        print(ch, end = ' ', file = Test)
                    else:
                        print(ch, end = ' ', file = Val)
                    for k in cur_par:
                        if IsTest:
                            print(k, end = ' ', file = Test)
                        else:
                            print(k, end = ' ', file = Val)
                    if IsTest:
                        print('', file = Test)
                    else:
                        print('', file = Val)
#                     if (cur_par[0]<0):
#                         charge = charge - 1
#                     else:
#                         charge = charge + 1
        if line == 'HepMC::IO_GenEvent-END_EVENT_LISTING':
            cur_exp[vertex] = cur_ver
            experiments.append(cur_exp)
            break
            
            
    cur_ver = []
    cur_exp = {}
    first_exp = True
#     first_ver = True
    vertex = 0
    Bparts = []
    i = 1           
    for line in lines:
        if line.startswith('E'):
            if vertex != 0:
                cur_exp[vertex] = cur_ver
#                 print(cur_ver)
                experiments.append(cur_exp)
                cur_exp = {}
#                 for exp in experiments:
#                     for pars in exp.values():
#                         for par in pars:
#                             print(par)
                ##need to clean the data of the Bparts
                Bparts = []
#                 mBparts = []
                vertex = 0
        elif line.startswith('V'):
            if vertex != 0:
                cur_exp[vertex] = cur_ver 
            cur_ver = []
            vertex += 1
        elif line.startswith('P'):
            pdata = line.split()
            cur_par = [int(pdata[2]), float(pdata[3]),
                               float(pdata[4]), float(pdata[5]),
                               float(pdata[6]), float(pdata[7]), 
                               int(pdata[11]), vertex]
            ##The second last one would be which vertex do particle decay 
            cur_ver.append(cur_par)
            ##when detecting 521 particles
            if int(pdata[2]) == -521:
                #meeting next 521 particle in different experiments
                Bparts = []                
                ran = random.randint(1, 5)
                if ran == 1:
                    IsTest = False
                else:
                    IsTest = True
                if IsTest:
                    print('E 0 ', i, file = Test)
                else:
                    print('E 0 ', i, file = Val)
                Bparts.append(int(pdata[11]))
                i = i + 1
#                 for j in cur_par:
#                     print(j, end = ' ', file = Val)
#                 print('', file = Val)
#                 print(cur_par, file = Output)
            if In(-cur_par[7], Bparts, len(Bparts)):
                Bparts.append(int(pdata[11]))
                if (cur_par[6] == 0):
                    ch = charge_dic.get(cur_par[0], 0)
                    if IsTest:
                        print(ch, end = ' ', file = Test)
                    else:
                        print(ch, end = ' ', file = Val)
                    for k in cur_par:
                        if IsTest:
                            print(k, end = ' ', file = Test)
                        else:
                            print(k, end = ' ', file = Val)
                    if IsTest:
                        print('', file = Test)
                    else:
                        print('', file = Val)
        if line == 'HepMC::IO_GenEvent-END_EVENT_LISTING':
            cur_exp[vertex] = cur_ver
            experiments.append(cur_exp)
            break
    Input.close()
    Test.close()
    Val.close()

# %%
# #electron: +11 (charge=-1)
# position: -11 (charge=+1)
# muon: +13 (charge=-1)
# anti-muon: -13 (charge=+1)
# K+: +321 (charge=+1)
# K-: -321 (charge=-1)
# pi+: +211 (charge=+1)
# pi-: -211 (charge=-1)
# proton: 2212 (charge=+1)
# anti-proton: -2212 (charge=-1)
charge_dic = {}
charge_dic[11] = -1
charge_dic[-11] = 1
charge_dic[13] = -1
charge_dic[-13] = 1
charge_dic[321] = 1
charge_dic[-321] = -1
charge_dic[211] = 1
charge_dic[-211] = -1
charge_dic[2212] = 1
charge_dic[-2212] = -1
experiments = []
ReadFile('hepMCtest', 'train.txt', 'val.txt', experiments, charge_dic)

# %%
ls = [1,2,3,4]
n = 5
print(In(n, ls, len(ls)))
# Out:
# False

# %%
def Readpxpypz(filepath, px, py, pz):
    with open(filepath, 'r') as file:
        lines = file.readlines()
    cur_exp = []
    experiments = []
    first = True

    for line in lines:
        if line.startswith('E'):
            if first and not cur_exp:
                first = False
            else:
                experiments.append(cur_exp)
                cur_exp = []
        elif line.startswith('P'):
            pdata = line.split()
            cur_par = [int(pdata[2]), float(pdata[3]),
                               float(pdata[4]), float(pdata[5]),
                               float(pdata[6]), float(pdata[6]),
                               float(pdata[7]), int(pdata[11])]
            if cur_par[7] == 0:
                px.append(cur_par[1]+20)
                py.append(cur_par[2]+20)
                pz.append(cur_par[3]+20)
            cur_exp.append(cur_par)
        if line == 'HepMC::IO_GenEvent-END_EVENT_LISTING':
            experiments.append(cur_exp)
            break
